# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish-k723/100-days-of-DL/blob/main/FunctionalAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model

# %%
from keras.layers import *

# %%
x = Input(shape = (3,))

# %%
hidden1 = Dense(128, activation = 'relu')(x)
hidden2 = Dense(64, activation = 'relu')(hidden1)

output1 = Dense(1, activation= 'linear')(hidden2)
output2 = Dense(1, activation = 'linear')(hidden2)

# %%
model = Model(inputs = x, outputs = [output1, output2])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 3)]          0           []
#
#  dense (Dense)                  (None, 128)          512         ['input_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            65          ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 1)            65          ['dense_1[0][0]']
#
# ...
# Total params: 8,898
# Trainable params: 8,898
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, show_shapes = True)

# %% [markdown]
# # Model-2

# %%
inputA = Input(shape = (32,))
inputB = Input(shape = (128,))

# %%
x = Dense(8, activation = "relu")(inputA)
x1 = Dense(4, activation = "relu")(x)

# %%
y = Dense(64, activation = "relu")(inputB)
y1 = Dense(32, activation = "relu")(y)
y2 = Dense(4, activation = "relu")(y1)

# %%
combined = concatenate([x1, y2])

# %%
z = Dense(2, activation = "relu")(combined)
z1 = Dense(1, activation = "relu")(z)

# %%
model = Model(inputs = [inputA, inputB], outputs = z1)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 128)]        0           []
#
#  input_3 (InputLayer)           [(None, 32)]         0           []
#
#  dense_6 (Dense)                (None, 64)           8256        ['input_4[0][0]']
#
#  dense_4 (Dense)                (None, 8)            264         ['input_3[0][0]']
#
#  dense_7 (Dense)                (None, 32)           2080        ['dense_6[0][0]']
#
#  dense_5 (Dense)                (None, 4)            36          ['dense_4[0][0]']
#
#  dense_8 (Dense)                (None, 4)            132         ['dense_7[0][0]']
#
#  concatenate (Concatenate)      (None, 8)            0           ['dense_5[0][0]',
#                                                                   'dense_8[0][0]']
#
# ...

# %%
plot_model(model,show_shapes = True )
