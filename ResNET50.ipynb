# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish-k723/100-days-of-DL/blob/main/ResNET50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import tensorflow
from tensorflow import keras
from keras.utils import load_img, img_to_array, array_to_img
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions

# %%
model = ResNet50(weights = 'imagenet')
# Out:
# ...
# 102967424/102967424 [==============================] - 0s 0us/step

# %%
img_path = '/content/dog.jpg'
img = load_img(img_path, target_size = (224,224))
x = img_to_array(img)
x = np.expand_dims(x, axis = 0) #It convert image into batch
print(x.shape)
x = preprocess_input(x)
# Out:
# (1, 224, 224, 3)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
preds = model.predict(x)
print(f'Decoded Predictions:{decode_predictions(preds, top = 5)}')
# Out:
# 1/1 [==============================] - 0s 139ms/step
# Decoded Predictions:[[('n02106030', 'collie', 0.456718), ('n02113186', 'Cardigan', 0.32420146), ('n02110806', 'basenji', 0.06983721), ('n02091244', 'Ibizan_hound', 0.038793124), ('n02113023', 'Pembroke', 0.034469243)]]
